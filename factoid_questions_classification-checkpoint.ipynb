# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re as re
import nltk as nl
from nltk import word_tokenize, pos_tag, bigrams

sns.set
pd.options.display.max_colwidth = 200

# %%
data_raw = pd.read_csv('C:\\Users\\DELL\\Desktop\\Akshay\\Datasets\\factoid_questions_classification\\factoid_questions_dataset.txt', sep='delimiter', header=None, names=['Factoids'], dtype={'Factoids':str})
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
data_raw
# Out:
#                                                                                                 Factoids
# 0                                         DESC:manner How did serfdom develop in and then leave Russia ?
# 1                                           ENTY:cremat What films featured the character Popeye Doyle ?
# 2                                        DESC:manner How can I find a list of celebrities ' real names ?
# 3                       ENTY:animal What fowl grabs the spotlight after the Chinese Year of the Monkey ?
# 4                                                               ABBR:exp What is the full form of .com ?
# ..                                                                                                   ...
# 995                                    DESC:manner How do you look up criminal records on the Internet ?
# 996                                            LOC:other Where is the actress , Marion Davies , buried ?
# 997                   DESC:desc What is an example of an actual case of using the Fourteenth Amendment ?
# 998                                                          HUM:ind Who was the Charlie perfume woman ?
# 999  HUM:ind Who portrayed `` Rosanne Rosanna-Dana '' on the television show `` Saturday Night Live '' ?
#
# [1000 rows x 1 columns]

# %%
data_raw['Factoids'] = data_raw.Factoids.str.replace(':', ' ')
data_raw['Class'] = data_raw.Factoids.str.split('\s+').str[0]
data_raw['Sub-Class'] = data_raw.Factoids.str.split('\s+').str[1]
data_raw['Questions'] = data_raw.Factoids.str.split('\s+').str[2:]
data_raw.drop('Factoids', axis=1)
# Out:
#     Class Sub-Class  \
# 0    DESC    manner
# 1    ENTY    cremat
# 2    DESC    manner
# 3    ENTY    animal
# 4    ABBR       exp
# ..    ...       ...
# 995  DESC    manner
# 996   LOC     other
# 997  DESC      desc
# 998   HUM       ind
# 999   HUM       ind
#
#                                                                                                         Questions
# 0                                                   [How, did, serfdom, develop, in, and, then, leave, Russia, ?]
# 1                                                       [What, films, featured, the, character, Popeye, Doyle, ?]
# 2                                                [How, can, I, find, a, list, of, celebrities, ', real, names, ?]
# 3                              [What, fowl, grabs, the, spotlight, after, the, Chinese, Year, of, the, Monkey, ?]
# 4                                                                        [What, is, the, full, form, of, .com, ?]
# ..                                                                                                            ...
# 995                                             [How, do, you, look, up, criminal, records, on, the, Internet, ?]
# 996                                                    [Where, is, the, actress, ,, Marion, Davies, ,, buried, ?]
# 997                       [What, is, an, example, of, an, actual, case, of, using, the, Fourteenth, Amendment, ?]
# 998                                                                   [Who, was, the, Charlie, perfume, woman, ?]
# 999  [Who, portrayed, ``, Rosanne, Rosanna-Dana, '', on, the, television, show, ``, Saturday, Night, Live, '', ?]
#
# [1000 rows x 3 columns]

# %%
data_raw.Questions.to_numpy()
# Out:
# array([list(['How', 'did', 'serfdom', 'develop', 'in', 'and', 'then', 'leave', 'Russia', '?']),
#        list(['What', 'films', 'featured', 'the', 'character', 'Popeye', 'Doyle', '?']),
#        list(['How', 'can', 'I', 'find', 'a', 'list', 'of', 'celebrities', "'", 'real', 'names', '?']),
#        list(['What', 'fowl', 'grabs', 'the', 'spotlight', 'after', 'the', 'Chinese', 'Year', 'of', 'the', 'Monkey', '?']),
#        list(['What', 'is', 'the', 'full', 'form', 'of', '.com', '?']),
#        list(['What', 'contemptible', 'scoundrel', 'stole', 'the', 'cork', 'from', 'my', 'lunch', '?']),
#        list(['What', 'team', 'did', 'baseball', "'s", 'St.', 'Louis', 'Browns', 'become', '?']),
#        list(['What', 'is', 'the', 'oldest', 'profession', '?']),
#        list(['What', 'are', 'liver', 'enzymes', '?']),
#        list(['Name', 'the', 'scar-faced', 'bounty', 'hunter', 'of', 'The', 'Old', 'West', '.']),
#        list(['When', 'was', 'Ozzy', 'Osbourne', 'born', '?']),
#        list(['Why', 'do', 'heavier', 'objects', 'travel', 'downhill', 'faster', '?']),
#        list(['Who', 'was', 'The', 'Pride', 'of', 'the', 'Yankees', '?']),
#        list(['Who', 'killed', 'Gandhi', '?']),
#        list(['What', 'is', 'considered', 'the', 'costliest', 'disaster', 'the', 'insurance', 'industry', 'has', 'ever', 'faced', '?']),
#        list(['What', 'sprawling', 'U.S.', 'state', 'boasts', 'the', 'most', 'airports', '?']),
#        list(['What', 'did', 'the', 'only', 'repealed', 'amendment', 'to', 'the', 'U.S.', 'Constitution', 'deal', 'with', '?']),
#        list(['How', 'many', 'Jews', 'were', 'executed', 'in', 'concentration', 'camps', 'during', 'WWII', '?']),
#        list(['What', 'is', '``', 'Nine', 'Inch', 'Nails', "''", '?']),
#        list(['What', 'is', 'an', 'annotated', 'bibliography', '?']),
#        list(['What', 'is', 'the', 'date', 'of', 'Boxing', 'Day', '?']),
#        list(['What', 'articles', 'of', 'clothing', 'are', 'tokens', 'in', 'Monopoly', '?']),
#        list(['Name', '11', 'famous', 'martyrs', '.']),
#        list(['What', "'s", 'the', 'Olympic', 'motto', '?']),
#        list(['What', 'is', 'the', 'origin', 'of', 'the', 'name', '`', 'Scarlett', "'", '?']),
#        list(['What', "'s", 'the', 'second-most-used', 'vowel', 'in', 'English', '?']),
#        list(['Who', 'was', 'the', 'inventor', 'of', 'silly', 'putty', '?']),
#        list(['What', 'is', 'the', 'highest', 'waterfall', 'in', 'the', 'United', 'States', '?']),
#        list(['Name', 'a', 'golf', 'course', 'in', 'Myrtle', 'Beach', '.']),
#        list(['Which', 'two', 'states', 'enclose', 'Chesapeake', 'Bay', '?']),
#        list(['What', 'does', 'the', 'abbreviation', 'AIDS', 'stand', 'for', '?']),
#        list(['What', 'does', 'a', 'spermologer', 'collect', '?']),
#        list(['How', 'many', 'points', 'make', 'up', 'a', 'perfect', 'fivepin', 'bowling', 'score', '?']),
#        list(['Which', 'company', 'that', 'manufactures', 'video-game', 'hardware', 'sells', 'the', '``', 'super', 'system', "''", '?']),
#        list(['How', 'many', 'Community', 'Chest', 'cards', 'are', 'there', 'in', 'Monopoly', '?']),
#        list(['What', 'do', 'Mormons', 'believe', '?']),
#        list(['When', 'did', 'the', 'neanderthal', 'man', 'live', '?']),
#        list(['In', 'what', 'religion', 'was', 'Isis', 'the', 'nature', 'goddess', '?']),
#        list(['Where', 'do', 'the', 'adventures', 'of', '``', 'The', 'Swiss', 'Family', 'Robinson', "''", 'take', 'place', '?']),
#        list(['What', 'relative', 'of', 'the', 'racoon', 'is', 'sometimes', 'known', 'as', 'the', 'cat-bear', '?']),
#        list(['How', 'can', 'I', 'register', 'my', 'website', 'in', 'Yahoo', 'for', 'free', '?']),
#        list(['What', 'was', 'cash-conscious', 'Colonel', 'Edwin', 'L.', 'Drake', 'the', 'first', 'to', 'drill', '?']),
#        list(['How', 'many', 'people', 'in', 'the', 'world', 'speak', 'French', '?']),
#        list(['How', 'many', 'inches', 'over', 'six', 'feet', 'is', 'the', 'Venus', 'de', 'Milo', '?']),
#        list(['How', 'do', 'they', 'find', 'or', 'choose', 'witnesses', 'to', 'an', 'execution', '?']),
#        list(['What', '1920s', 'cowboy', 'star', 'rode', 'Tony', 'the', 'Wonder', 'Horse', '?']),
#        list(['What', 'cocktail', 'inspired', 'John', 'Doxat', 'to', 'write', 'the', 'book', 'Stirred-Not', 'Shaken', '?']),
#        list(['What', 'ISPs', 'exist', 'in', 'the', 'Caribbean', '?']),
#        list(['How', 'do', 'you', 'ask', 'a', 'total', 'stranger', 'out', 'on', 'a', 'date', '?']),
#        list(['What', 'weapon', 'is', 'the', 'mythological', 'character', 'Apollo', 'most', 'proficient', 'with', '?']),
#        list(['What', 'country', 'do', 'the', 'Galapagos', 'Islands', 'belong', 'to', '?']),
#        list(['What', 'is', 'ethology', '?']),
#        list(['Who', 'was', 'the', 'prophet', 'of', 'the', 'Muslim', 'people', '?']),
#        list(['Where', 'did', 'the', 'term', '``', '86ed', "''", 'come', 'from', '?']),
#        list(['Who', 'is', 'Snoopy', "'s", 'arch-enemy', '?']),
#        list(['What', 'is', 'the', 'nature', 'of', 'learning', '?']),
#        list(['What', "'s", 'the', 'only', 'color', 'Johnny', 'Cash', 'wears', 'on', 'stage', '?']),
#        list(['What', "'s", 'the', 'term', 'for', 'a', 'young', 'fox', '?']),
#        list(['What', 'U.S.', 'state', 'lived', 'under', 'six', 'flags', '?']),
#        list(['What', 'is', 'the', 'Kashmir', 'issue', '?']),
#        list(['Where', 'is', 'the', 'Loop', '?']),
#        list(['What', 'does', '``', 'extended', 'definition', "''", 'mean', 'and', 'how', 'would', 'one', 'write', 'a', 'paper', 'on', 'it', '?']),
#        list(['What', 'country', "'s", 'capital', 'is', 'Tirana', '?']),
#        list(['What', 'is', 'titanium', '?']),
#        list(['Who', 'do', 'Herb', 'and', 'Tootsie', 'live', 'next', 'door', 'to', '?']),
#        list(['Which', 'city', 'has', 'the', 'oldest', 'relationship', 'as', 'a', 'sisterðcity', 'with', 'Los', 'Angeles', '?']),
#        list(['What', 'is', 'a', 'caldera', '?']),
#        list(['Why', 'do', 'people', 'get', 'calluses', '?']),
#        list(['What', 'are', 'the', 'names', 'of', 'the', 'tourist', 'attractions', 'in', 'Reims', '?']),
#        list(['What', 'are', 'Cushman', 'and', 'Wakefield', 'known', 'for', '?']),
#        list(['What', 'body', 'of', 'water', 'does', 'the', 'Danube', 'River', 'flow', 'into', '?']),
#        list(['Who', 'is', 'the', 'founder', 'of', 'Scientology', '?']),
#        list(['What', 'does', 'the', 'six-footed', 'Musca', 'domestica', 'become', 'when', 'it', 'enters', 'a', 'house', '?']),
#        list(['What', 'is', 'the', 'history', 'of', 'skateboarding', '?']),
#        list(['Who', 'starred', 'in', 'Singing', 'in', 'the', 'Rain', 'and', 'The', 'Singing', 'Nun', '?']),
#        list(['How', 'do', 'I', 'make', 'fuel', 'bricks', 'from', 'recycled', 'newspaper', '?']),
#        list(['What', '19th-century', 'painter', 'died', 'in', 'the', 'Marquesas', 'Islands', '?']),
#        list(['The', 'corpus', 'callosum', 'is', 'in', 'what', 'part', 'of', 'the', 'body', '?']),
#        list(['How', 'do', 'I', 'log', 'on', 'to', 'home', 'page', 'at', 'Headquarters', 'U.S.', 'European', 'Command', '?']),
#        list(['What', 'country', 'did', 'the', 'Nazis', 'occupy', 'for', '1', ',', 'CD', 'NNS', 'IN', 'NNP', 'NNP', 'NNP', '.']),
#        list(['What', 'is', 'Nebraska', "'s", 'most', 'valuable', 'resource', '?']),
#        list(['How', 'many', 'species', 'of', 'the', 'Great', 'White', 'shark', 'are', 'there', '?']),
#        list(['What', 'is', 'the', 'origin', 'of', 'head', 'lice', '?']),
#        list(['What', 'is', 'the', 'nickname', 'for', 'the', 'state', 'of', 'Mississippi', '?']),
#        list(['What', 'was', 'the', 'first', 'domesticated', 'bird', '?']),
#        list(['How', 'many', 'villi', 'are', 'found', 'in', 'the', 'small', 'intestine', '?']),
#        list(['What', 'country', 'did', 'King', 'Wenceslas', 'rule', '?']),
#        list(['What', 'is', 'a', 'fear', 'of', 'shadows', '?']),
#        list(['Who', 'were', 'the', 'five', 'Marx', 'brothers', '?']),
#        list(['In', 'which', 'year', 'was', 'New', 'Zealand', 'excluded', 'from', 'the', 'ANZUS', 'alliance', '?']),
#        list(['When', 'did', 'CNN', 'begin', 'broadcasting', '?']),
#        list(['What', 'causes', 'the', 'body', 'to', 'shiver', 'in', 'cold', 'temperatures', '?']),
#        list(['What', 'are', 'bear', 'and', 'bull', 'markets', '?']),
#        list(['What', 'J.R.R.', 'Tolkien', 'book', 'features', 'Bilbo', 'Baggins', 'as', 'the', 'central', 'character', '?']),
#        list(['What', 'is', '``', 'dew', 'point', "''", '?']),
#        list(['What', 'is', 'the', 'meaning', 'of', 'Jesus', '?']),
#        list(['What', 'company', "'s", 'logo', 'is', 'a', '``', 'W', "''", 'in', 'a', 'circle', '?']),
#        list(['What', 'is', 'the', 'definition', 'of', 'a', 'cascade', '?']),
#        list(['When', 'did', 'Rococo', 'painting', 'and', 'architecture', 'flourish', '?']),
#        list(['What', 'country', "'s", 'national', 'passenger', 'rail', 'system', 'is', 'called', 'Via', '?']),
#        list(['Who', 'invented', 'Make-up', '?']),
#        list(['What', 'is', 'the', 'origin', 'of', 'the', 'word', '``', 'attic', "''", '?']),
#        list(['What', 'did', 'Delilah', 'do', 'to', 'Samson', "'s", 'hair', '?']),
#        list(['What', 'kind', 'of', 'animals', 'were', 'in', 'the', 'Paleozoic', 'era', '?']),
#        list(['Which', 'of', 'the', 'following', 'was', 'Rhodes', 'Scholar', '?']),
#        list(['Who', 'comprised', 'the', 'now-defunct', 'comic', 'book', 'team', 'known', 'as', 'the', 'Champions', '?']),
#        list(['How', 'do', 'you', 'make', 'a', 'paintball', '?']),
#        list(['What', 'U.S.', 'state', 'is', 'Fort', 'Knox', 'in', '?']),
#        list(['What', 'is', 'a', 'female', 'rabbit', 'called', '?']),
#        list(['Where', 'is', 'the', 'highest', 'point', 'in', 'Japan', '?']),
#        list(['Where', 'do', 'chihuahuas', 'come', 'from', '?']),
#        list(['Where', 'does', 'Barney', 'Rubble', 'go', 'to', 'work', 'after', 'he', 'drops', 'Fred', 'off', 'in', 'the', '``', 'Flintstones', "''", 'cartoon', 'series', '?']),
#        list(['What', 'are', 'the', 'world', "'s", 'four', 'oceans', '?']),
#        list(['What', "'s", 'the', 'only', 'work', 'by', 'Michelangelo', 'that', 'bears', 'his', 'signature', '?']),
#        list(['What', 'is', 'the', 'largest', 'snake', 'in', 'the', 'world', '?']),
#        list(['In', 'what', 'medium', 'is', 'Stuart', 'Hamblen', 'considered', 'to', 'be', 'the', 'first', 'singing', 'cowboy', '?']),
#        list(['Where', 'on', 'the', 'Internet', 'can', 'I', 'find', 'a', 'song', 'lyrics', 'database', 'similar', 'to', 'the', 'International', 'Lyrics', 'Server', '?']),
#        list(['How', 'much', 'money', 'does', 'a', 'back', 'injury', 'lawsuit', 'get', '?']),
#        list(['What', "'s", 'the', 'common', 'name', 'for', 'acetylsalicylic', 'acid', '?']),
#        list(['What', 'does', 'the', 'Georgetown', '``', 'Hoya', "''", 'mean', '?']),
#        list(['Where', 'can', 'I', 'find', 'a', 'list', 'of', '``', 'classic', "''", 'books', '5th', 'and', '6th', 'graders', 'should', 'read', '?']),
#        list(['Which', 'two', 'products', 'use', 'a', 'tiger', 'as', 'their', 'symbol', '?']),
#        list(['How', 'is', 'the', 'election', 'of', 'a', 'new', 'Pope', 'announced', 'to', 'the', 'world', '?']),
#        list(['How', 'long', 'does', 'it', 'take', 'for', 'your', 'blood', 'to', 'make', 'one', 'complete', 'trip', 'through', 'the', 'body', '?']),
#        list(['How', 'do', 'chickens', 'have', 'baby', 'chicks', '?']),
#        list(['What', 'is', 'the', 'historical', 'relationship', 'of', 'Catholic', 'Church', 'and', 'bingo', '?']),
#        list(['How', 'was', 'the', 'element', 'calcium', 'named', '?']),
#        list(['What', 'crooner', 'joined', 'The', 'Andrews', 'Sisters', 'for', 'Pistol', 'Packin', 'Mama', '?']),
#        list(['What', 'piano', 'company', 'claims', 'its', 'product', 'is', 'the', '``', 'Instrument', 'of', 'the', 'immortals', "''", '?']),
#        list(['When', 'did', 'the', 'Bounty', 'mutiny', 'take', 'place', '?']),
#        list(['What', 'novel', 'inspired', 'the', 'movie', 'BladeRunner', '?']),
#        list(['What', 'is', 'a', 'transistor', '?']),
#        list(['What', 'is', 'a', 'film', 'starring', 'Jude', 'Law', '?']),
#        list(['What', 'Hollywood', 'dog', 'died', 'in', 'the', 'arms', 'of', 'Jean', 'Harlow', 'in', '1932', '?']),
#        list(['What', 'are', 'the', 'most', 'common', 'elements', 'in', 'the', 'Earth', "'s", 'crust', '?']),
#        list(['How', 'much', 'would', 'it', 'cost', 'to', 'purchase', 'a', '2-foot-square', 'party', 'tent', ',', 'with', 'sides', ',', '?']),
#        list(['What', 'actress', 'has', 'received', 'the', 'most', 'Oscar', 'nominations', '?']),
#        list(['What', 'are', 'equity', 'securities', '?']),
#        list(['What', 'is', 'gymnophobia', '?']),
#        list(['How', 'many', 'years', 'do', 'fossils', 'take', 'to', 'form', '?']),
#        list(['Where', 'is', 'the', 'Orinoco', '?']),
#        list(['What', 'was', 'the', 'name', 'of', 'the', '``', 'Little', 'Rascals', "''", 'dog', '?']),
#        list(['What', 'city', 'boasts', 'Penn', "'s", 'Landing', ',', 'on', 'the', 'banks', 'of', 'the', 'Delaware', 'river', '?']),
#        list(['What', 'Broadway', 'musical', 'was', 'inspired', 'by', 'Cervantes', "'s", 'Don', 'Quixote', '?']),
#        list(['What', 'is', 'the', 'origin', 'of', 'the', 'word', ',', 'JJ', '.']),
#        list(['How', 'many', 'hostages', 'were', 'killed', 'in', 'the', 'Entebbe', 'raid', '?']),
#        list(['How', 'you', 'can', 'raise', 'your', 'IQ', '?']),
#        list(['What', 'does', 'INRI', 'stand', 'for', 'when', 'used', 'on', 'Jesus', "'", 'cross', '?']),
#        list(['Who', 'produces', 'Spumante', '?']),
#        list(['Who', 'earns', 'their', 'money', 'the', 'hard', 'way', '?']),
#        list(['Who', 'founded', 'the', 'People', "'s", 'Temple', 'Commune', '?']),
#        list(['What', 'athlete', 'makes', 'the', 'most', 'money', 'from', 'sports', 'merchandise', 'sales', '?']),
#        list(['How', 'many', 'bends', 'are', 'there', 'in', 'a', 'standard', 'paper', 'clip', '?']),
#        list(['Who', 'discovered', 'electricity', '?']),
#        list(['What', 'part', 'of', 'your', 'body', 'contains', 'the', 'corpus', 'callosum', '?']),
#        list(['Who', 'was', 'the', 'first', 'American', 'in', 'space', '?']),
#        list(['What', 'two', 'South', 'American', 'countries', 'do', "n't", 'border', 'Brazil', '?']),
#        list(['What', 'album', 'put', 'The', 'Beatles', 'on', 'the', 'cover', 'of', 'Time', 'in', '1967', '?']),
#        list(['What', 'poem', 'contains', 'the', 'line', ',', '``', 'grow', 'old', 'with', 'me', 'the', 'best', 'is', 'yet', 'to', 'be', "''", '.']),
#        list(['What', 'is', 'a', 'dental', 'root', 'canal', '?']),
#        list(['What', 'war', 'did', 'the', 'Wanna-Go-Home', 'Riots', 'occur', 'after', '?']),
#        list(['What', 'is', 'the', 'busiest', 'air', 'travel', 'season', '?']),
#        list(['What', "'s", 'the', 'colored', 'part', 'of', 'the', 'eye', 'called', '?']),
#        list(['What', 'are', 'hook', 'worms', '?']),
#        list(['Where', 'is', 'the', 'Rose', 'Bowl', 'played', '?']),
#        list(['Which', 'Japanese', 'car', 'maker', 'had', 'its', 'biggest', 'percentage', 'of', 'sale', 'in', 'the', 'domestic', 'market', '?']),
#        list(['Who', 'is', 'the', 'mayor', 'of', 'Marbella', '?']),
#        list(['What', 'sun-blasted', ',', '14-mile', 'wide', 'valley', 'is', 'just', 'north', 'of', 'the', 'Mojave', 'desert', '?']),
#        list(['In', 'what', 'year', 'did', 'Thatcher', 'become', 'prime', 'minister', '?']),
#        list(['How', 'many', 'months', 'does', 'it', 'take', 'the', 'moon', 'to', 'revolve', 'around', 'the', 'Earth', '?']),
#        list(['Where', 'are', 'the', '49', 'steps', '?']),
#        list(['In', 'what', 'year', 'was', 'De', 'Gaulle', 'elected', 'president', 'of', 'France', '?']),
#        list(['Who', 'sings', 'the', 'themes', 'for', '``', 'Dawson', "'s", 'Creek', "''", 'and', '``', 'Felicity', "''", '?']),
#        list(['Who', 'directed', '``', 'Jaws', "''", '?']),
#        list(['On', 'what', 'T.V.', 'show', 'could', 'Tom', 'Terrific', 'be', 'found', '?']),
#        list(['What', 'Indian', 'tribe', 'is', 'F', 'Troop', 'perpetually', 'doing', 'battle', 'with', '?']),
#        list(['Where', 'did', 'Indian', 'Pudding', 'come', 'from', '?']),
#        list(['Why', 'do', 'some', 'clothing', 'labels', 'say', '``', 'Use', 'a', 'nonchlorine', 'bleach', "''", '?']),
#        list(['How', 'many', 'colonies', 'were', 'involved', 'in', 'the', 'American', 'Revolution', '?']),
#        list(['What', 'is', 'the', 'name', 'of', 'the', 'city', 'that', 'Maurizio', 'Pellegrin', 'lives', 'in', '?']),
#        list(['Where', 'can', 'I', 'find', 'pictorial', 'directions', 'on', 'how', 'to', 'build', 'a', 'very', 'simple', 'treehouse', '?']),
#        list(['What', 'game', "'s", 'board', 'shows', 'the', 'territories', 'of', 'Irkutsk', ',', 'Yakutsk', 'and', 'Kamchatka', '?']),
#        list(['What', 'is', 'the', 'name', 'of', 'the', 'managing', 'director', 'of', 'Apricot', 'Computer', '?']),
#        list(['What', 'is', 'the', 'occupation', 'of', 'Nicholas', 'Cage', '?']),
#        list(['Why', 'do', 'horseshoes', 'bring', 'luck', '?']),
#        list(['What', 'is', 'the', '401', ',', 'K', ',', 'plan', '?']),
#        list(['What', 'causes', 'pneumonia', '?']),
#        list(['What', 'are', 'the', 'three', 'winter', 'months', 'in', 'the', 'southern', 'hemisphere', '?']),
#        list(['What', 'does', 'gringo', 'mean', '?']),
#        list(['What', 'country', 'contains', 'Africa', "'s", 'northernmost', 'point', '?']),
#        list(['What', 'therapy', 'attempts', 'to', 'elicit', 'the', '``', 'primal', 'scream', "''", '?']),
#        list(['Where', 'is', 'the', 'Kalahari', 'desert', '?']),
#        list(['Which', 'Ventura', 'County', 'police', 'department', 'seized', 'the', 'largest', 'cocaine', 'shipment', 'in', 'it', "'s", 'history', '?']),
#        list(['What', 'city', 'is', 'sometimes', 'called', 'Gotham', '?']),
#        list(['What', 'dangles', 'over', 'the', 'tongue', 'from', 'the', 'palate', '?']),
#        list(['Who', 'created', 'Dennis', 'the', 'Menace', '?']),
#        list(['What', 'dummy', 'received', 'an', 'honorary', 'degree', 'from', 'Northwestern', 'University', '?']),
#        list(['When', 'was', 'the', 'first', 'Wall', 'Street', 'Journal', 'published', '?']),
#        list(['What', 'countries', 'have', 'the', 'largest', 'areas', 'of', 'forest', '?']),
#        list(['How', 'do', 'I', 'start', 'a', 'web', 'based', 'business', '?']),
#        list(['Name', 'Alvin', "'s", 'brothers']),
#        list(['What', 'is', 'Eagle', "'s", 'syndrome', 'styloid', 'process', '?']),
#        list(['How', 'did', 'Jayne', 'Mansfield', 'die', '?']),
#        list(['When', 'did', 'the', 'royal', 'wedding', 'of', 'Prince', 'Andrew', 'and', 'Fergie', 'take', 'place', '?']),
#        list(['What', 'actor', 'said', 'in', 'A', 'Day', 'at', 'the', 'Races', '``', 'Either', 'he', "'s", 'dead', 'or', 'my', 'watch', 'has', 'stopped', "''", '?']),
#        list(['What', 'explorer', 'was', 'nicknamed', 'Iberia', "'s", 'Pilot', '?']),
#        list(['CNN', 'began', 'broadcasting', 'in', 'what', 'year', '?']),
#        list(['What', 'is', 'a', 'ball', 'that', 'hits', 'the', 'foul', 'pole', 'called', '?']),
#        list(['What', 'makes', 'hamburgers', 'taste', 'like', 'steakburgers', '?']),
#        list(['Which', 'company', 'created', 'the', 'Internet', 'browser', 'Mosaic', '?']),
#        list(['What', 'are', 'the', 'rites', 'accompanying', 'the', 'circumcision', 'of', 'a', 'newly', 'born-child', 'in', 'Judaism', 'called', '?']),
#        list(['What', 'was', 'the', 'education', 'system', 'in', 'the', '1960', "'s", '?']),
#        list(['What', 'South', 'American', 'city', 'has', 'the', 'world', "'s", 'highest', 'commercial', 'landing', 'field', '?']),
#        list(['How', 'can', 'I', 'find', 'out', 'which', 'cities', 'have', 'cable-modem', 'access', '?']),
#        list(['What', 'is', 'Betsy', 'Ross', 'famous', 'for', '?']),
#        list(['How', 'many', 'species', 'of', 'sharks', 'are', 'there', '?']),
#        list(['What', 'is', '``', 'snoogans', "''", '?']),
#        list(['How', 'many', 'people', 'are', 'there', 'in', 'the', 'world', '?']),
#        list(['What', 'shrubs', 'can', 'be', 'planted', 'that', 'will', 'be', 'safe', 'from', 'deer', '?']),
#        list(['What', 'organization', "'s", 'offices', 'were', 'broken', 'into', 'at', 'Watergate', 'in', '1972', '?']),
#        list(['What', 'is', 'the', 'design', 'of', 'the', 'ship', 'Titanic', '?']),
#        list(['What', 'does', 'S.O.S.', 'stand', 'for', '?']),
#        list(['Name', 'a', 'technique', 'widely', 'used', 'to', 'detect', 'birth', 'defects', '?']),
#        list(['What', 'is', 'the', 'daily', 'requirement', 'of', 'folic', 'acid', 'for', 'an', 'expectant', 'mother', '?']),
#        list(['What', 'is', 'the', '``', '7-minute', 'cigarette', "''", '?']),
#        list(['What', 'four', 'forms', 'does', 'gold', 'occur', 'in', '?']),
#        list(['What', 'is', 'the', 'acreage', 'of', 'the', 'Chappellet', 'vineyard', '?']),
#        list(['How', 'do', 'you', 'correctly', 'say', 'the', 'word', '`', 'qigong', "'", '?']),
#        list(['When', 'did', 'beethoven', 'die', '?']),
#        list(['How', 'much', 'does', 'a', 'new', 'railroad', 'coal', 'car', 'cost', '?']),
#        list(['What', 'two', 'European', 'countries', 'entered', 'the', 'War', 'of', 'American', 'Independence', 'against', 'the', 'British', '?']),
#        list(['What', 'is', 'the', 'filmmakers', 'collabrative', '?']),
#        list(['What', 'Russian', 'composer', "'s", 'Prelude', 'in', 'C', 'Sharp', 'Minor', 'brought', 'him', 'fame', 'and', 'fortune', '?']),
#        list(['What', 'caused', 'Harry', 'Houdini', "'s", 'death', '?']),
#        list(['Who', 'was', 'the', 'mother', 'of', 'the', 'man', 'who', 'would', 'not', 'be', 'king', ',', 'the', 'duke', 'of', 'Windsor', '?']),
#        list(['How', 'many', 'revolutions', 'does', 'a', 'standard', 'LP', 'make', 'in', 'three', 'minutes', '?']),
#        list(['What', 'is', 'the', 'name', 'of', 'the', 'tallest', 'mountain', 'in', 'the', 'world', '?']),
#        list(['Where', 'can', 'I', 'find', 'a', 'review', 'of', 'Nightmare', 'on', 'Elm', 'Street', 'in', 'a', 'film', 'journal', '?']),
#        list(['What', "'s", 'the', 'slowest', 'Olympic', 'swimming', 'stroke', '?']),
#        list(['What', 'was', 'the', 'name', 'of', 'the', 'first', 'Russian', 'astronaut', 'to', 'do', 'a', 'spacewalk', '?']),
#        list(['What', 'disease', 'is', 'transmitted', 'by', 'the', 'Anopheles', 'mosquito', '?']),
#        list(['What', 'rum', 'is', 'so', '``', 'mixable', "''", 'it', 'is', 'a', 'one-brand', 'bar', '?']),
#        list(['How', 'many', 'South', 'American', 'countries', 'have', 'the', 'letter', 'Z', 'in', 'their', 'names', '?']),
#        list(['What', 'is', 'the', 'contents', 'of', 'proposition', '98', '?']),
#        list(['Where', 'was', 'George', 'Washington', 'born', '?']),
#        list(['How', 'many', 'people', 'on', 'the', 'ground', 'were', 'killed', 'from', 'the', 'bombing', 'of', 'Pan', 'Am', 'Flight', '103', 'over', 'Lockerbie', ',', 'Scotland', ',', 'December', '21', ',', 'CD', '.']),
#        list(['Who', 'wrote', 'NN', 'DT', 'NNP', 'NNP', "''", '?']),
#        list(['What', 'is', 'paracetamol', '?']),
#        list(['What', 'are', 'the', 'powers', 'and', 'weaknesses', 'of', 'Green', 'Lantern', "'s", 'ring', '?']),
#        list(['Which', 'mosquito', "'s", 'bite', 'draws', 'blood', ',', 'DT', 'NN', 'CC', 'DT', 'NN', '.']),
#        list(['When', 'was', 'the', 'first', 'steel', 'mill', 'in', 'the', 'United', 'States', 'built', '?']),
#        list(['What', 'diminutive', 'American', 'female', 'gymnast', 'stole', 'the', 'show', 'at', 'the', '1984', 'Olympics', '?']),
#        list(['What', 'is', 'the', 'origin', 'of', 'the', 'name', 'Katie', '?']),
#        list(['What', 'schools', 'in', 'the', 'Washington', ',', 'DC', 'NN', 'NN', 'VBP', 'NN', 'NN', 'NN', 'NN', '.']),
#        list(['When', 'did', 'the', 'Berlin', 'Wall', 'go', 'up', '?']),
#        list(['Who', 'is', 'Terrence', 'Malick', '?']),
#        list(['What', 'instrument', 'is', 'Ray', 'Charles', 'best', 'known', 'for', 'playing', '?']),
#        list(['What', "'s", 'the', 'meaning', 'of', 'the', 'Latin', 'battle', 'cry', 'Ad', 'arma', ',', 'ad', 'arma', '.']),
#        list(['What', 'is', 'the', 'mascot', 'for', 'Notre', 'Dame', 'University', '?']),
#        list(['What', 'Las', 'Vegas', 'hotel', 'burned', 'in', 'November', ',', '1980', ',', 'with', 'the', 'loss', 'of', '84', 'lives', '?']),
#        list(['When', 'did', 'Mount', 'St.', 'Helen', 'last', 'have', 'a', 'significant', 'eruption', '?']),
#        list(['CNN', 'is', 'the', 'abbreviation', 'for', 'what', '?']),
#        list(['When', 'did', 'World', 'War', 'I', 'start', '?']),
#        list(['How', 'many', 'feet', 'are', 'there', 'in', 'a', 'fathom', '?']),
#        list(['What', 'is', 'a', 'Canada', 'two-penny', 'black', '?']),
#        list(['What', 'European', 'city', 'do', 'Nicois', 'live', 'in', '?']),
#        list(['How', 'can', 'I', 'find', 'out', 'what', 'year', 'a', 'Beanie', 'Baby', 'was', 'introduced', '?']),
#        list(['What', 'is', 'the', 'classic', 'definition', 'of', 'tragic', 'hero', '?']),
#        list(['To', 'what', 'does', 'Microsoft', "'s", 'Windows', '3', 'owe', 'its', 'success', '?']),
#        list(['Who', 'was', 'President', 'of', 'Afghanistan', 'in', '1994', '?']),
#        list(['What', 'are', 'other', 'ways', 'of', 'getting', 'stretch', 'marks', 'besides', 'pregnancy', ',', 'weight', 'loss', ',', 'and', 'weight', 'lifting', '?']),
#        list(['What', 'did', 'brontosauruses', 'eat', '?']),
#        list(['What', 'color', 'bottles', 'do', 'good', 'Rhine', 'wines', 'come', 'in', '?']),
#        list(['Who', 'was', 'the', 'lead', 'actress', 'in', 'the', 'movie', '`', 'Sleepless', 'in', 'Seattle', "'", '?']),
#        list(['Who', 'was', 'the', '16th', 'President', 'of', 'the', 'United', 'States', '?']),
#        list(['Who', 'are', 'the', 'two', 'sons', 'of', 'Ozzie', 'and', 'Harriet', 'Nelson', '?']),
#        list(['What', 'is', 'molybdenum', '?']),
#        list(['When', 'is', 'Boxing', 'Day', '?']),
#        list(['What', 'is', 'the', 'lowest', 'level', 'of', 'the', 'American', 'judiciary', '?']),
#        list(['When', 'was', 'the', 'battle', 'of', 'the', 'Somme', 'fought', '?']),
#        list(['How', 'many', 'people', 'did', 'Randy', 'Craft', 'kill', '?']),
#        list(['What', "'s", 'the', 'official', 'animal', 'of', 'Canada', '?']),
#        list(['When', 'did', 'Spielberg', 'direct', '``', 'Jaws', "''", '?']),
#        list(['What', 'is', 'the', 'size', 'of', 'the', 'largest', 'akita', '?']),
#        list(['What', 'animal', 'has', 'the', 'biggest', 'eyes', '?']),
#        list(['What', 'is', 'California', "'s", 'capital', '?']),
#        list(['Who', 'was', 'the', 'author', 'of', 'the', 'book', 'about', 'computer', 'hackers', 'called', '``', 'The', 'Cuckoo', "'s", 'Egg', 'Tracking', 'a', 'Spy', 'Through', 'the', 'Maze', 'of', 'Computer', 'Espionage', "''", '?']),
#        list(['Who', 'was', 'the', 'founding', 'member', 'of', 'the', 'Pink', 'Floyd', 'band', '?']),
#        list(['What', 'European', 'country', 'is', 'home', 'to', 'the', 'beer-producing', 'city', 'of', 'Budweis', '?']),
#        list(['How', 'do', 'I', 'find', 'the', 'balance', 'of', 'my', 'social', 'security', 'account', '?']),
#        list(['What', 'is', 'the', 'history', 'of', 'Valentine', "'s", 'Day', 'cards', '?']),
#        list(['Where', 'was', 'Christopher', 'Columbus', 'born', '?']),
#        list(['What', 'do', 'Italians', 'call', 'Florence', '?']),
#        list(['How', 'do', 'you', 'get', 'to', 'the', 'top', 'of', 'the', 'Eiffel', 'Tower', '?']),
#        list(['What', 'does', '`', 'PSI', "'", 'stand', 'for', '?']),
#        list(['What', 'sea', 'did', 'the', 'Romans', 'call', 'mare', 'nostrum', '?']),
#        list(['What', "'s", 'the', 'term', 'for', 'a', 'bet', 'before', 'cards', 'are', 'dealt', '?']),
#        list(['Which', 'came', 'first', ',', 'according', 'to', 'Genesis', '1', '2', '22', '-', 'the', 'chicken', 'or', 'the', 'egg', '?']),
#        list(['What', 'city', 'did', 'the', 'Flintstones', 'live', 'in', '?']),
#        list(['What', 'is', 'Latin', 'for', 'incompetent', '?']),
#        list(['What', 'chemicals', 'are', 'used', 'in', 'lethal', 'injection', '?']),
#        list(['What', 'toy', 'company', 'is', 'the', 'world', "'s", 'No.1', 'maker', 'of', 'female', 'apparel', '?']),
#        list(['What', 'board', 'game', 'does', 'a', '``', 'wood-pusher', "''", 'play', 'poorly', '?']),
#        list(['Which', 'Doonesbury', 'character', 'was', 'likely', 'to', 'turn', 'into', 'a', 'werewolf', '?']),
#        list(['What', 'is', 'the', 'abbreviation', 'for', 'micro', '?']),
#        list(['What', 'are', 'the', '7', 'articles', 'of', 'the', 'constitution', '?']),
#        list(['Who', 'has', 'won', 'the', 'most', 'Super', 'Bowls', '?']),
#        list(['What', 'does', 'NASDAQ', 'stand', 'for', '?']),
#        list(['What', 'is', 'BPH', '?']),
#        list(['What', 'is', 'the', 'fastest', 'commercial', 'automobile', 'that', 'can', 'be', 'bought', 'in', 'the', 'US', '?']),
#        list(['What', 'stadium', 'do', 'the', 'Miami', 'Dolphins', 'play', 'their', 'home', 'games', 'in', '?']),
#        list(['Who', 'has', 'the', 'only', 'speaking', 'role', 'in', '``', 'Silent', 'Movie', "''", '?']),
#        list(['Why', 'is', 'poop', 'sometimes', 'different', 'colors', '?']),
#        list(['What', 'was', 'Einstein', "'s", 'IQ', '?']),
#        list(['What', 'day', 'was', 'Pearl', 'Harbor', 'attacked', 'in', '1942', '?']),
#        list(['What', 'girl', "'s", 'name', 'is', '``', 'Teddy', "''", 'an', 'affectionate', 'form', 'of', '?']),
#        list(['What', 'state', 'is', 'John', 'F.', 'Kennedy', 'buried', 'in', '?']),
#        list(['What', 'is', 'the', 'best', 'way', 'to', 'remove', 'wallpaper', '?']),
#        list(['What', 'U.S.', 'state', 'has', 'an', 'element', 'named', 'for', 'it', '?']),
#        list(['What', 'company', 'tabulates', 'the', 'ballots', 'in', 'voting', 'for', 'the', 'Academy', 'Awards', '?']),
#        list(['How', 'did', 'the', 'tradition', 'of', 'best', 'man', 'start', '?']),
#        list(['How', 'many', 'years', 'ago', 'did', 'the', 'ship', 'Titanic', 'sink', '?']),
#        list(['What', 'is', 'the', 'deepest', 'area', 'of', 'the', 'Arctic', 'Ocean', '?']),
#        list(['What', 'are', 'Halloween', "'s", 'colors', '?']),
#        list(['How', 'is', 'silk', 'screening', 'done', '?']),
#        list(['What', 'is', 'the', 'latitude', 'and', 'longitude', 'of', 'El', 'Paso', ',', 'Texas', '?']),
#        list(['Who', 'made', 'a', 'boat', 'out', 'of', 'gopher', 'wood', '?']),
#        list(['Where', 'can', 'I', 'find', 'a', '``', 'Fifth', 'Element', "''", 'screensaver', '?']),
#        list(['Which', 'Bloom', 'County', 'resident', 'wreaks', 'havoc', 'with', 'a', 'computer', '?']),
#        list(['How', 'do', 'you', 'match', 'a', 'name', 'to', 'a', 'social', 'security', 'number', '?']),
#        list(['How', 'does', 'a', 'rainbow', 'form', '?']),
#        list(['What', 'is', 'the', 'normal', 'resting', 'heart', 'rate', 'of', 'a', 'healthy', 'adult', '?']),
#        list(['What', 'is', 'the', 'population', 'of', 'Ohio', '?']),
#        list(['How', 'many', 'calories', 'are', 'there', 'in', 'a', 'Big', 'Mac', '?']),
#        list(['Hazmat', 'stands', 'for', 'what', '?']),
#        list(['What', 'creature', 'scares', 'people', 'in', 'the', 'film', '``', 'Jaws', "''", '?']),
#        list(['What', 'part', 'did', 'John', 'Peter', 'Zenger', 'play', 'in', 'the', 'deveopment', 'of', 'the', 'newspaper', 'in', 'America', '?']),
#        list(['Who', 'followed', 'Caesar', '?']),
#        list(['What', 'are', 'the', 'four', 'elements', '?']),
#        list(['Who', 'was', 'the', 'first', 'woman', 'golfer', 'to', 'earn', 'a', 'million', '?']),
#        list(['What', "'s", 'the', 'tallest', 'piece', 'on', 'a', 'chessboard', '?']),
#        list(['What', 'is', 'Answers.com', "'s", 'address', '?']),
#        list(['Where', 'can', 'I', 'buy', 'movies', 'on', 'videotape', 'online', '?']),
#        list(['Who', 'does', 'the', 'advertizing', 'for', 'Frito-Lay', '?']),
#        list(['Who', 'is', 'the', 'leading', 'competitor', 'of', 'Trans', 'Union', 'Company', '?']),
#        list(['What', 'product', 'did', 'Robert', 'Conrad', 'dare', 'people', 'to', 'knock', 'off', 'his', 'shoulder', '?']),
#        list(['Who', 'invented', 'the', 'radio', '?']),
#        list(['What', "'s", 'the', 'American', 'dollar', 'equivalent', 'for', '8', 'pounds', 'in', 'the', 'U.K.', '?']),
#        list(['What', 'are', 'the', 'different', 'approaches', 'of', 'systems', 'analysis', '?']),
#        list(['How', 'do', 'doctors', 'diagnose', 'bone', 'cancer', '?']),
#        list(['Who', 'is', 'the', 'man', 'behind', 'the', 'pig-the', 'man', 'who', 'pulls', 'the', 'strings', 'and', 'speaks', 'for', 'Miss', 'Piggy', '?']),
#        list(['What', 'is', 'the', 'speed', 'of', 'the', 'Mississippi', 'River', '?']),
#        list(['What', 'are', 'the', 'developmental', 'stages', 'of', 'a', 'swimmer', '?']),
#        list(['What', 'actor', 'first', 'portrayed', 'James', 'Bond', '?']),
#        list(['What', 'ocean', 'is', 'the', 'largest', 'in', 'the', 'world', '?']),
#        list(['Who', 'was', 'the', 'first', 'American', 'poet', 'to', 'win', 'the', 'Nobel', 'Prize', 'for', 'literature', ',', 'in', '1948', '?']),
#        list(['What', 'year', 'did', 'Jack', 'Nicklaus', 'join', 'the', 'Professional', 'Golfers', 'Association', 'tour', '?']),
#        list(['How', 'many', 'sonnets', 'did', 'Shakespeare', 'write', '?']),
#        list(['What', 'causes', 'the', 'redness', 'in', 'your', 'cheeks', 'when', 'you', 'blush', '?']),
#        list(['Who', 'won', 'the', 'Nobel', 'Peace', 'Prize', 'in', '1991', '?']),
#        list(['Who', 'are', 'the', 'Challengers', 'of', 'the', 'Unknown', '?']),
#        list(['Define', 'the', 'Pheonix', 'Club', '?']),
#        list(['Which', 'city', 'did', 'Christian', 'Crusaders', 'fight', 'to', 'recapture', 'from', 'the', 'Muslims', '?']),
#        list(['What', 'does', 'it', 'mean', '``', 'Rupee', 'Depreciates', "''", '?']),
#        list(['What', 'gaming', 'devices', 'were', 'dubbed', '``', 'Mississippi', 'marbles', "''", 'and', '``', 'Memphis', 'dominoes', "''", '?']),
#        list(['Who', 'was', 'the', 'first', 'coach', 'of', 'the', 'Cleveland', 'Browns', '?']),
#        list(['How', 'successful', 'is', 'arometherapy', '?']),
#        list(['What', 'Jewish', 'holiday', 'saw', 'the', 'start', 'of', 'the', '1973', 'Mideast', 'War', '?']),
#        list(['How', 'does', 'a', 'copier', 'work', '?']),
#        list(['What', 'is', 'the', 'speed', 'of', 'the', 'Mississippi', 'River', '?']),
#        list(['Who', 'said', 'of', 'Super', 'Bowl', 'III', 'in', '1969', '``', 'We', "'ll", 'win-', 'I', 'guarantee', 'it', "''", '?']),
#        list(['What', 'is', 'Dudley', 'Do-Right', "'s", 'horse', "'s", 'name', '?']),
#        list(['Who', 'declared', '``', 'I', 'am', 'down', 'on', 'whores', 'and', 'I', 'shan', "'t", 'stop', 'ripping', 'them', "''", '?']),
#        list(['Where', 'does', 'chocolate', 'come', 'from', '?']),
#        list(['What', 'TV', 'game', 'show', 'once', 'saw', 'a', 'contestant', 'admit', 'to', 'picking', 'his', 'toes', 'in', 'the', 'shower', '?']),
#        list(['What', 'Soviet', 'leader', 'owned', 'a', 'Rolls-Royce', '?']),
#        list(['Where', 'can', 'I', 'find', 'a', 'case', 'on', 'Individuals', 'with', 'Disabilities', 'Education', 'Act', 'of', '1991', '?']),
#        list(['What', 'war', 'did', 'Florence', 'Nightingale', 'tend', 'the', 'troops', 'in', '?']),
#        list(['Who', 'wrote', 'the', 'song', ',', '``', 'Stardust', "''", '?']),
#        list(['How', 'many', 'Beatles', "'", 'records', 'went', '#1', '?']),
#        list(['Who', 'is', 'the', 'only', 'prime', 'minister', 'of', 'Canada', 'to', 'serve', '22', 'years', 'but', 'not', 'necessarily', 'consecutively', '?']),
#        list(['What', 'is', 'the', 'abbreviation', 'of', 'the', 'company', 'name', '`', 'General', 'Motors', "'", '?']),
#        list(['What', 'mountains', 'lie', 'between', 'the', 'Arkansas', 'and', 'Missouri', 'rivers', '?']),
#        list(['Who', 'received', 'the', 'Will', 'Rogers', 'Award', 'in', '1989', '?']),
#        list(['What', 'is', 'the', 'function', 'of', 'RAM', '?']),
#        list(['What', "'s", 'the', 'closest', 'G2', 'Spectrum', 'Yellow', 'Dwarf', 'to', 'Earth', '?']),
#        list(['How', 'many', 'equal', 'angles', 'are', 'there', 'in', 'an', 'isosceles', 'triangle', '?']),
#        list(['What', 'is', 'the', 'fear', 'of', 'cockroaches', 'called', '?']),
#        list(['What', 'CBS', 'soap', 'opera', 'was', 'interrupted', 'by', 'the', 'bulletin', 'of', 'John', 'F.', 'Kennedy', "'s", 'assassination', '?']),
#        list(['What', 'is', 'the', 'use', 'of', 'a', '24-hour', 'clock', 'instead', 'of', 'a', '12-hour', 'clock', '?']),
#        list(['What', 'was', 'the', 'name', 'of', 'the', 'lawyer', 'who', 'represented', 'Randy', 'Craft', '?']),
#        list(['What', 'United', 'States', 'President', 'had', 'dreamed', 'that', 'he', 'was', 'assassinated', '?']),
#        list(['What', 'film', 'did', 'Lee', 'Marvin', 'win', 'the', '1965', 'best', 'actor', 'Oscar', 'for', '?']),
#        list(['Where', 'is', 'Basque', 'country', 'located', '?']),
#        list(['What', 'product', 'does', '``', 'Mrs.', 'Olsen', "''", 'promote', '?']),
#        list(['What', 'time', 'of', 'day', 'did', 'Emperor', 'Hirohito', 'die', '?']),
#        list(['What', 'is', 'dry', 'ice', '?']),
#        list(['What', "'s", 'the', 'most', 'powerful', 'card', 'in', 'Euchre', '?']),
#        list(['What', 'does', '``', 'intractable', 'plantar', 'keratoma', "''", 'mean', '?']),
#        list(['How', 'many', 'years', 'did', 'it', 'take', 'James', 'Joyce', 'to', 'write', 'Ulysses', '?']),
#        list(['What', 'crop', 'failure', 'caused', 'the', 'Irish', 'Famine', '?']),
#        list(['What', 'South', 'Korean', 'city', 'is', 'served', 'by', 'Kimpo', 'International', 'Airport', '?']),
#        list(['How', 'many', 'types', 'of', 'dogs', "'", 'tails', 'are', 'there', '-', 'three']),
#        list(['What', 'is', 'the', 'longest-running', 'television', 'series', '?']),
#        list(['What', 'predators', 'exist', 'on', 'Antarctica', '?']),
#        list(['What', 'is', 'the', 'difference', 'between', 'a', 'generator', 'and', 'an', 'alternator', '?']),
#        list(['How', 'is', 'energy', 'created', '?']),
#        list(['What', 'beer', 'advertised', 'that', 'it', 'had', '``', 'three', 'rings', "''", '?']),
#        list(['What', 'is', 'the', 'quantity', 'of', 'American', 'soldiers', 'still', 'unaccounted', 'for', 'from', 'the', 'Vietnam', 'war', '?']),
#        list(['What', 'golfing', 'accessory', 'was', 'patented', 'by', 'George', 'Grant', 'on', 'December', '12']),
#        list(['What', 'are', 'the', 'different', 'types', 'of', 'plastic', '?']),
#        list(['How', 'is', 'it', 'correct', 'to', 'say', '`', 'qigong', "'", '?']),
#        list(['What', 'was', 'the', 'highest', 'mountain', 'on', 'earth', 'before', 'Mount', 'Everest', 'was', 'discovered', '?']),
#        list(['Where', 'was', 'the', 'Ligurian', 'Republic', ',', '1797-185', ',', '?']),
#        list(['What', 'country', "'s", 'people', 'are', 'the', 'top', 'television', 'watchers', '?']),
#        list(['When', 'was', 'the', 'women', "'s", 'suffrage', 'amendment', 'ratified', '?']),
#        list(['What', 'Polynesian', 'people', 'inhabit', 'New', 'Zealand', '?']),
#        list(['What', 'movie', 'tour', 'of', 'the', 'Roman', 'empire', 'features', 'the', 'admonition', '``', 'Row', 'well', 'and', 'live', "''", '?']),
#        list(['What', 'Nevada', 'center', 'has', 'been', 'dubbed', 'The', 'Biggest', 'Little', 'City', 'in', 'the', 'World', '?']),
#        list(['What', 'President', 'lived', 'at', '219', 'North', 'Delaware', 'Street', ',', 'Independence', ',', 'Missouri', '?']),
#        list(['Give', 'a', 'reason', 'for', 'American', 'Indians', 'oftentimes', 'dropping', 'out', 'of', 'school', '.']),
#        list(['Where', 'must', 'a', 'soccer', 'goalie', 'stand', 'to', 'be', 'permitted', 'to', 'handle', 'the', 'ball', '?']),
#        list(['What', 'is', 'the', 'difference', 'between', 'classical', 'conditioning', 'and', 'operant', 'conditioning', '?']),
#        list(['In', 'what', 'U.S.', 'state', 'was', 'the', 'first', 'woman', 'governor', 'elected', '?']),
#        list(['What', 'are', 'some', 'interesting', 'facts', 'and', 'information', 'about', 'dogsledding', '?']),
#        list(['What', 'year', 'did', 'Hitler', 'die', '?']),
#        list(['What', 'famous', 'model', 'was', 'married', 'to', 'Billy', 'Joel', '?']),
#        list(['What', 'kind', 'of', 'animal', 'is', 'Babar', '?']),
#        list(['What', 'is', 'Jane', 'Goodall', 'known', 'for', '?']),
#        list(['What', 'killed', 'Bob', 'Marley', '?']),
#        list(['How', 'much', 'money', 'are', 'Dumbo', "'s", 'ears', 'insured', 'for', '?']),
#        list(['Who', 'danced', 'into', 'stardom', 'with', 'Fred', 'Astaire', 'in', '1941', "'s", 'You', "'ll", 'Never', 'Get', 'Rich', '?']),
#        list(['Who', 'is', 'Stein', 'Eriksen', '?']),
#        list(['What', 'does', 'the', 'name', 'Billie', 'mean', '?']),
#        list(['Who', 'is', 'the', 'fastest', 'swimmer', 'in', 'the', 'world', '?']),
#        list(['What', 'is', 'the', 'highest', 'peak', 'in', 'Africa', '?']),
#        list(['Where', 'is', 'Procter', '&', 'Gamble', 'headquartered', 'in', 'the', 'U.S.', '?']),
#        list(['What', 'desert', 'has', 'been', 'called', 'The', 'Garden', 'of', 'Allah', '?']),
#        list(['What', 'do', 'bicornate', 'animals', 'have', 'two', 'of', '?']),
#        list(['What', 'function', 'does', 'a', 'community', "'s", 'water', 'tower', 'serve', '?']),
#        list(['What', 'is', 'a', 'fear', 'of', 'weakness', '?']),
#        list(['How', 'many', 'miles', 'is', 'it', 'to', 'Ohio', 'from', 'North', 'Carolina', '?']),
#        list(['How', 'much', 'snow', 'equals', 'an', 'inch', 'of', 'rain', '?']),
#        list(['What', 'does', 'G.M.T.', 'stand', 'for', '?']),
#        list(['What', 'does', 'Inuit', 'and', 'Eskimo', 'mean', '?']),
#        list(['What', 'song', 'served', 'as', 'the', 'closing', 'theme', 'of', 'The', 'Johnny', 'Cash', 'Show', '?']),
#        list(['What', 'field', 'sport', 'did', 'dentist', 'William', 'Beers', 'promote', 'and', 'write', 'a', 'standard', 'book', 'of', 'rules', 'for', '?']),
#        list(['How', 'do', 'I', 'tie', 'dye', 'clothes', '?']),
#        list(['When', 'does', 'the', 'average', 'teenager', 'first', 'have', 'intercourse', '?']),
#        list(['Why', 'doesn', "'t", 'www.answers.com', 'have', 'any', 'answers', 'to', 'my', 'questions', '?']),
#        list(['What', 'actor', "'s", 'autobiography', 'is', 'titled', 'All', 'My', 'Yesterdays', '?']),
#        list(['What', 'Russian', 'master', 'spy', 'lived', 'in', 'the', 'U.S.', 'under', 'the', 'name', 'Emil', 'Goldfus', '?']),
#        list(['Where', "'s", 'the', '19th', 'hole', 'on', 'a', 'golf', 'course', '?']),
#        list(['What', "'s", 'nature', "'s", 'purpose', 'for', 'tornadoes', '?']),
#        list(['Who', 'played', 'the', 'original', 'Charlie', "'s", 'Angels', '?']),
#        list(['Where', 'can', 'I', 'find', 'a', 'person', "'s", 'address', 'from', 'a', 'telephone', 'number', '?']),
#        list(['What', 'English', 'word', 'comes', 'from', 'the', 'Old', 'French', 'covrefeu', ',', 'meaning', 'cover', 'fire', '?']),
#        list(['What', 'musical', 'instrument', 'did', 'Prewitt', 'play', 'in', 'James', 'Jones', "'s", 'From', 'Here', 'to', 'Eternity', '?']),
#        list(['Where', 'did', 'Sarge', 'Steel', 'get', 'his', 'metal', 'hand', '?']),
#        list(['What', 'makes', 'popcorn', 'pop', '?']),
#        list(['Who', 'wrote', 'The', 'Night', 'of', 'the', 'Iguana', '?']),
#        list(['Where', 'does', 'your', 'hair', 'grow', 'the', 'fastest', '?']),
#        list(['What', 'country', 'did', 'King', 'Gustav', 'V', 'reign', 'over', 'from', '197', 'to', '195', '?']),
#        list(['Who', 'painted', 'Mother', 'and', 'Child', '?']),
#        list(['What', 'is', 'the', 'speed', 'of', 'the', 'Mississippi', 'River', '?']),
#        list(['In', 'what', 'area', 'of', 'the', 'world', 'was', 'the', 'Six', 'Day', 'War', 'fought', '?']),
#        list(['What', 'is', 'the', 'brightest', 'star', 'visible', 'from', 'Earth', '?']),
#        list(['What', 'film', 'marked', 'Robert', 'Redford', "'s", 'directorial', 'debut', '?']),
#        list(['What', 'was', 'Mao', "'s", 'second', 'name', '?']),
#        list(['What', 'film', 'or', 'films', 'has', 'Jude', 'Law', 'appeared', 'in', '?']),
#        list(['Where', 'do', 'hyenas', 'live', '?']),
#        list(['Who', 'is', 'the', '``', 'Queen', 'Mother', "''", '?']),
#        list(['What', "'s", 'the', 'most', 'commonly-spoken', 'language', 'in', 'Belgium', '?']),
#        list(['Who', 'has', 'more', 'DNA', '-', 'a', 'man', 'or', 'a', 'woman', '?']),
#        list(['What', 'are', 'Maid-Rites', '?']),
#        list(['What', 'children', "'s", 'tale', 'contains', 'the', 'line', '``', 'Come', ',', 'Cinderslut', ',', 'and', 'hold', 'this', 'skein', 'of', 'wool', 'for', 'me', "''", '?']),
#        list(['What', 'level', 'of', 'government', 'or', 'governmental', 'agency', 'is', 'responsible', 'for', 'dealing', 'with', 'racism', '?']),
#        list(['How', 'many', 'referees', 'work', 'a', 'soccer', 'game', '?']),
#        list(['What', 'cocktail', 'do', 'you', 'concoct', 'with', 'whisky', 'and', 'sweet', 'vermouth', '?']),
#        list(['How', 'do', 'you', 'say', '``', 'fresh', "''", 'in', 'Spanish', '?']),
#        list(['What', 'do', 'bee', 'hives', 'do', 'in', 'cranberry', 'bogs', '?']),
#        list(['What', 'caused', 'the', 'Lynmouth', 'floods', '?']),
#        list(['When', 'is', 'the', 'Tulip', 'Festival', 'in', 'Michigan', '?']),
#        list(['Who', 'came', 'up', 'with', 'the', 'name', ',', 'El', 'Nino', '?']),
#        list(['What', 'movie', 'did', 'Madilyn', 'Kahn', 'star', 'in', 'with', 'Gene', 'Wilder', '?']),
#        list(['What', 'type', 'of', 'bridge', 'is', 'the', 'Golden', 'Gate', 'Bridge', '?']),
#        list(['What', 'dictator', 'has', 'the', 'nickname', '``', 'El', 'Maximo', "''", '?']),
#        list(['What', 'stereo', 'manufacturer', 'is', '``', 'Slightly', 'ahead', 'of', 'its', 'time', "''", '?']),
#        list(['What', 'U.S.', 'city', 'is', 'The', 'Queen', 'of', 'the', 'Pacific', '?']),
#        list(['What', 'TV', 'sitcom', 'character', 'had', 'the', 'maiden', 'name', 'Ethel', 'Potter', '?']),
#        list(['What', 'was', 'the', 'first', 'Lifesaver', 'flavor', '?']),
#        list(['Who', 'kept', 'the', 'most', 'famous', 'diary', 'in', 'the', 'English', 'language', '?']),
#        list(['Where', 'can', 'I', 'find', 'out', 'the', 'top', '1', 'singles', '?']),
#        list(['How', 'many', 'degrees', 'cooler', 'is', 'the', 'inside', 'of', 'a', 'cucumber', 'than', 'the', 'air', 'outside', '?']),
#        list(['What', 'Spanish', 'artist', 'painted', 'Crucifixion', '?']),
#        list(['What', 'is', 'the', 'Jewish', 'bible', 'called', '?']),
#        list(['Why', 'is', 'the', 'grass', 'green', '?']),
#        list(['What', 'is', 'a', 'firewall', '?']),
#        list(['What', 'spy', 'novelist', 'served', 'as', 'Moscow', 'correspondent', 'for', 'Reuter', 'and', 'The', 'Times', 'of', 'London', '?']),
#        list(['Which', 'oil', 'company', 'almost', 'picked', 'a', 'word', 'that', 'meant', '``', 'stalled', 'car', "''", 'in', 'Japanese', 'as', 'its', 'new', 'international', 'name', '?']),
#        list(['How', 'long', 'does', 'it', 'take', 'for', 'Spider-Man', "'s", 'web', 'to', 'evaporate', '?']),
#        list(['Who', 'was', 'Randy', 'Steven', 'Craft', "'s", 'lawyer', '?']),
#        list(['What', 'was', 'known', 'as', 'the', 'Spice', 'Island', '?']),
#        list(['Who', 'was', 'the', 'first', 'host', 'of', 'Person', 'to', 'Person', '?']),
#        list(['Name', 'the', 'Ranger', 'who', 'was', 'always', 'after', 'Yogi', 'Bear', '.']),
#        list(['What', 'deck', 'of', 'cards', 'includes', 'the', 'Wheel', 'of', 'Fortune', ',', 'the', 'Lovers', ',', 'and', 'Death', '?']),
#        list(['What', 'does', 'the', 'Statue', 'of', 'Liberty', 'wear', 'on', 'her', 'feet', '?']),
#        list(['Who', 'is', 'the', 'superstar', 'in', 'rent-a-cars', '?']),
#        list(['McCarren', 'Airport', 'is', 'located', 'in', 'what', 'city', '?']),
#        list(['What', 'household', 'facility', 'contains', 'a', 'float', 'ball', ',', 'ballcock', ',', 'and', 'overflow', 'tube', '?']),
# ...
#        list(['What', 'is', 'November', "'s", 'birthstone', '?']),
#        list(['What', 'is', 'a', 'Certified', 'Nurse', 'Midwife', '?']),
#        list(['On', 'average', ',', 'how', 'many', 'miles', 'are', 'there', 'to', 'the', 'moon', '?']),
#        list(['Who', 'created', 'private', 'detective', 'Philip', 'Marlowe', '?']),
#        list(['What', 'Boris', 'Pasternak', 'book', 'sold', '5', ',', '0', 'copies', 'to', 'become', 'the', 'fiction', 'best-seller', 'of', '1958', '?']),
#        list(['What', 'is', 'the', 'origin', 'of', 'the', 'expression', '``', 'tout', 'de', 'suite', "''", '?']),
#        list(['What', 'is', 'the', 'longest', 'English', 'word', '?']),
#        list(['What', 'is', 'the', 'purpose', 'of', 'a', 'car', 'bra', '?']),
#        list(['What', 'is', 'D.B.', 'Cooper', 'known', 'for', '?']),
#        list(['Who', 'is', 'Colin', 'Powell', '?']),
#        list(['What', 'species', 'is', 'a', 'colt', '?']),
#        list(['What', 'is', 'the', 'full', 'name', 'of', 'the', 'PLO', '?']),
#        list(['What', 'is', 'the', 'smallest', 'country', 'in', 'Africa', '?']),
#        list(['Who', 'coined', 'the', 'term', 'NN', 'cyberspace', '``', 'in', 'his', 'novel', 'NN', 'Neuromancer', "''", '?']),
#        list(['What', 'age', 'followed', 'the', 'Bronze', 'Age', '?']),
#        list(['What', 'is', 'her', 'profession', '?']),
#        list(['What', 'is', 'the', 'full', 'name', 'of', 'the', 'man', 'who', 'invented', 'the', 'multicolored', 'game', 'cube', 'that', 'has', '42.3', 'quintillion', 'potential', 'combinations', '?']),
#        list(['What', 'does', 'the', 'word', 'LASER', 'mean', '?']),
#        list(['What', 'does', 'the', 'name', '``', 'Anthony', "''", 'mean', '?']),
#        list(['Who', 'was', 'Lauren', 'Bacall', "'s", 'first', 'husband', '?']),
#        list(['What', 'is', 'a', 'rhomboideus', 'minor', '?']),
#        list(['How', 'many', 'hands', 'does', 'Bjorn', 'Borg', 'use', 'when', 'hitting', 'his', 'forehand', '?']),
#        list(['How', 'many', 'people', 'died', 'on', 'D-Day', '?']),
#        list(['What', 'U.S.', 'Congressman', 'said', '``', 'Keep', 'the', 'faith', ',', 'baby', "''", '.']),
#        list(['Who', 'created', 'the', 'character', 'of', 'Scrooge', '?']),
#        list(['What', 'is', 'the', 'student', 'population', 'at', 'the', 'University', 'of', 'Massachusetts', 'in', 'Amherst', '?']),
#        list(['Where', 'is', 'Windsor', 'Castle', '?']),
#        list(['When', 'did', 'the', 'Dow', 'first', 'reach', '?']),
#        list(['Why', 'were', 'people', 'recruited', 'for', 'the', 'Vietnam', 'War', '?']),
#        list(['What', 'party', 'was', 'Winston', 'Churchill', 'a', 'member', 'of', '?']),
#        list(['What', 'American', 'League', 'baseball', 'team', "'s", 'worst', 'finish', 'between', '1926', 'and', '1964', 'was', 'fourth', '?']),
#        list(['Where', 'can', 'I', 'find', 'the', 'names', 'of', 'all', 'the', '15', 'Pokemon', '?']),
#        list(['What', 'state', 'does', 'Martha', 'Stewart', 'live', 'in', '?']),
#        list(['Which', 'killer', 'whale', 'died', 'at', 'Sea', 'World', 'of', 'a', 'fungal', 'infection', '?']),
#        list(['What', 'are', 'the', 'Benelux', 'countries', '?']),
#        list(['Where', "'s", 'the', 'Petrified', 'Forest', '?']),
#        list(['What', 'is', 'a', 'language', 'spoken', 'by', 'the', 'Sioux', '?']),
#        list(['Where', 'is', 'Tornado', 'Alley', '?']),
#        list(['Who', 'was', 'the', 'author', 'of', '``', 'John', 'Brown', "'s", 'Body', "''", '?']),
#        list(['What', 'American', 'poet', 'wrote', '``', 'Good', 'fences', 'make', 'good', 'neighbors', "''", '?']),
#        list(['What', 'state', 'in', 'the', 'U.S.', 'has', 'the', 'most', 'blacks', '?']),
#        list(['Why', 'are', 'electric', 'cars', 'less', 'efficient', 'in', 'the', 'northeast', 'than', 'in', 'California', '?']),
#        list(['What', 'was', 'the', 'occupation', 'of', 'Mandy', 'Rice-Davies', '?']),
#        list(['What', 'is', 'the', 'city', 'in', 'which', 'Maurizio', 'Pellegrin', 'lives', 'called', '?']),
#        list(['Who', 'painted', 'the', 'Sistine', 'Chapel', '?']),
#        list(['Name', 'the', 'various', 'costumed', 'personas', 'of', 'Dr.', 'Henry', 'Pym', '.']),
#        list(['What', 'breed', 'of', 'dog', 'was', 'the', '``', 'Little', 'Rascals', "''", 'dog', '?']),
#        list(['What', 'are', 'the', 'living', 'conditions', 'in', 'Cuba', '?']),
#        list(['What', 'color', 'are', 'school', 'buses', '?']),
#        list(['What', 'is', 'the', 'oldest', 'website', 'on', 'the', 'Internet', '?']),
#        list(['What', 'events', 'happened', 'January', '26', ',', '1978', '?']),
#        list(['What', 'explorers', 'followed', 'Columbus', 'to', 'the', 'Americas', '?']),
#        list(['Who', 'is', 'actress', 'Goldie', 'Hawn', "'s", 'current', 'actor', 'boyfriend', '?']),
#        list(['Who', 'banned', 'Peter', 'Rose', 'from', 'baseball', 'for', 'betting', 'on', 'games', '?']),
#        list(['What', 'are', 'the', 'seven', 'virtues', '?']),
#        list(['What', 'other', 'name', 'were', 'the', '``', 'Little', 'Rascals', "''", 'known', 'as', '?']),
#        list(['When', 'was', 'the', 'San', 'Francisco', 'fire', '?']),
#        list(['What', 'is', 'a', 'fear', 'of', 'food', '?']),
#        list(['How', 'many', 'casinos', 'are', 'in', 'Atlantic', 'City', ',', 'NJ', '?']),
#        list(['What', 'year', 'did', 'the', 'Vietnam', 'War', 'end', '?']),
#        list(['What', 'are', 'the', 'names', 'of', 'Richard', 'Nixon', "'s", 'two', 'daughters', '?']),
#        list(['What', "'s", 'the', 'word', 'for', 'broken', 'glass', 'or', 'sharp', 'rocks', 'embedded', 'in', 'cement', 'on', 'top', 'of', 'a', 'wall', '?']),
#        list(['What', 'is', 'the', 'chromosome', 'number', 'of', 'an', 'elephant', '?']),
#        list(['What', 'organization', 'was', 'founded', 'by', 'the', 'Rev.', 'Jerry', 'Falwell', '?']),
#        list(['What', "'s", 'the', 'longest', 'river', 'in', 'the', 'world', '?']),
#        list(['Which', 'soft', 'drink', 'does', 'Madonna', 'advertise', 'for', '?']),
#        list(['What', 'company', 'is', 'being', 'bought', 'by', 'Yahoo', 'and', 'how', 'much', 'is', 'the', 'deal', 'worth', '?']),
#        list(['When', 'was', 'Berlin', "'s", 'Brandenburg', 'gate', 'erected', '?']),
#        list(['How', 'many', 'double-word-score', 'spaces', 'are', 'there', 'on', 'a', 'Scrabble', 'Crossword', 'Game', 'board', '?']),
#        list(['What', 'year', 'did', 'Germany', 'sign', 'its', 'nonaggression', 'pact', 'with', 'the', 'Soviet', 'Union', '?']),
#        list(['What', 'mountain', 'range', 'is', 'traversed', 'by', 'the', 'highest', 'railroad', 'in', 'the', 'world', '?']),
#        list(['Why', 'were', 'the', 'American', 'soldiers', 'in', 'WWI', 'called', '``', 'Doughboys', "''"]),
#        list(['Who', 'was', 'nicknamed', 'The', 'Little', 'Corporal', '?']),
#        list(['How', 'many', 'CDs', 'has', 'Garth', 'Brooks', 'sold', '?']),
#        list(['Name', 'the', 'vessel', 'used', 'by', 'the', 'Atari', 'Force', 'in', 'the', 'DC', 'comics', '.']),
#        list(['Where', 'are', 'the', 'leading', 'medical', 'groups', 'specializing', 'in', 'lung', 'diseases', '?']),
#        list(['How', 'can', 'I', 'find', 'online', 'spelling', ',', 'and', 'punctuation', 'drills', 'for', 'my', '6th', 'grader', '?']),
#        list(['What', "'s", 'the', 'sacred', 'river', 'of', 'India', '?']),
#        list(['What', 'is', 'Stefan', 'Edberg', "'s", 'native', 'country', '?']),
#        list(['What', 'is', 'the', 'only', 'gland', 'in', 'humans', 'that', 'can', 'regenerate', 'itself', '?']),
#        list(['How', 'many', 'Gutenberg', 'Bibles', 'are', 'there', '?']),
#        list(['Name', 'the', 'largest', 'country', 'in', 'South', 'America', '.']),
#        list(['What', 'astronomical', 'phenomenon', 'takes', 'place', 'in', 'Jan.', '1999', '?']),
#        list(['What', 'information', 'can', 'you', 'get', 'me', 'on', 'Fairground', 'Park', 'in', 'St.', 'Louis']),
#        list(['What', 'was', 'American', 'folk', 'hero', 'John', 'Chapman', "'s", 'nickname', '?']),
#        list(['What', 'is', 'the', 'difference', 'between', 'a', 'median', 'and', 'a', 'mean', '?']),
#        list(['What', 'was', 'the', 'top', 'box', 'office', 'movie', 'in', 'April', '1998', '?']),
#        list(['What', 'makes', 'thunder', '?']),
#        list(['What', 'author', 'did', 'photographer', 'Yousuf', 'Karsh', 'call', '``', 'the', 'shiest', 'man', 'I', 'ever', 'met', "''", '?']),
#        list(['Which', 'is', 'the', 'largest', 'clock', ',', 'diameter', 'wise', ',', 'in', 'Europe', '?']),
#        list(['What', 'plant', 'is', 'rum', 'made', 'from', '?']),
#        list(['What', 'country', 'are', 'Godiva', 'chocolates', 'from', '?']),
#        list(['Name', 'the', 'poet', 'of', 'the', 'poem', 'which', 'begins', 'I', 'do', 'not', 'know', 'much', 'about', 'gods', ';', 'but', 'I', 'think', 'that', 'the', 'river', 'Is', 'a', 'strong', 'brown', 'god-sullen', ',', 'and', 'untamed', '?']),
#        list(['Which', 'condiment', 'was', 'once', 'sold', 'as', 'a', 'patent', 'medicine', '?']),
#        list(['What', 'U.S.', 'state', 'records', 'the', 'least', 'rainfall', '?']),
#        list(['Why', 'did', 'the', 'world', 'enter', 'a', 'global', 'depression', 'in', '1929', '?']),
#        list(['What', 'was', 'archy', ',', 'and', 'mehitabel', '?']),
#        list(['What', 'Texas', 'city', 'got', 'its', 'name', 'from', 'the', 'Spanish', 'for', '``', 'yellow', "''", '?']),
#        list(['What', 'are', 'the', 'chemicals', 'used', 'in', 'glowsticks', '?']),
#        list(['What', 'country', 'did', 'the', 'Nile', 'River', 'originate', 'in', '?']),
#        list(['What', 'color', 'are', 'tennis', 'balls', '?']),
#        list(['What', 'barroom', 'judge', 'called', 'himself', 'The', 'Law', 'West', 'of', 'the', 'Pecos', '?']),
#        list(['What', 'excuse', 'did', 'the', 'NATO', 'people', 'give', 'for', 'hitting', 'the', 'Chinese', 'embassy', '?']),
#        list(['Who', 'was', 'President', 'of', 'Costa', 'Rica', 'in', '1994', '?']),
#        list(['What', 'sports', 'event', 'is', 'Meyer', 'Wolfsheim', 'supposed', 'to', 'have', 'fixed', 'in', 'The', 'Great', 'Gatsby', '?']),
#        list(['What', 'country', 'has', 'the', 'best', 'defensive', 'position', 'in', 'the', 'board', 'game', 'Diplomacy', '?']),
#        list(['What', 'two', 'countries', 'share', 'the', 'Khyber', 'Pass', '?']),
#        list(['Who', 'was', 'chairman', 'of', 'the', 'Senate', 'select', 'committee', 'that', 'tried', 'to', 'get', 'to', 'the', 'bottom', 'of', 'Watergate', '?']),
#        list(['What', 'is', 'the', 'origin', 'of', 'the', 'surname', 'of', 'Braun', '?']),
#        list(['What', 'card', 'game', 'has', 'variations', 'called', 'Canfield', ',', 'Klondike', 'and', 'Spider', '?']),
#        list(['What', 'is', 'Australia', 'Day', '?']),
#        list(['What', 'mammal', 'of', 'North', 'America', 'is', 'the', 'world', "'s", 'longest-lived', 'for', 'its', 'size', '?']),
#        list(['What', 'was', 'the', 'Chivington', 'Massacre', '?']),
#        list(['What', 'actor', 'starred', 'in', '1980', "'s", 'Blue', 'Lagoon', ',', '1982', "'s", 'The', 'Pirate', 'Movie', 'and', '1983', "'s", 'A', 'Night', 'in', 'Heaven', '?']),
#        list(['How', 'many', 'home', 'runs', 'did', 'Lou', 'Gehrig', 'have', 'during', 'his', 'career', '?']),
#        list(['In', 'what', 'city', 'is', 'the', 'headquarters', 'of', 'Sinn', 'Fein', '?']),
#        list(['Where', 'can', 'I', 'find', 'information', 'on', 'George', 'Bush', '?']),
#        list(['Who', 'is', 'the', 'voice', 'of', 'Miss', 'Piggy', '?']),
#        list(['What', 'is', 'the', 'dialogue', 'circle', 'in', 'cartoons', 'called', '?']),
#        list(['What', 'does', 'the', 'word', 'camaro', 'mean', ',', 'from', 'the', 'GM', 'car', 'the', 'Camaro', '?']),
#        list(['Who', 'replaced', 'Bert', 'Parks', 'as', 'the', 'host', 'of', 'The', 'Miss', 'America', 'Pageant', '?']),
#        list(['How', 'many', 'boys', 'play', 'the', 'game', 'in', 'Winslow', 'Homer', "'s", '1872', 'painting', 'Snap', 'the', 'Whip', '?']),
#        list(['What', 'is', 'the', 'AIM-54C', 'Phoenix', '?']),
#        list(['When', 'are', 'sheep', 'shorn', '?']),
#        list(['What', 'sport', 'is', 'Chris', 'Jogis', 'a', 'top', 'player', 'of', '?']),
#        list(['What', "'s", 'the', 'second-largest', 'island', 'in', 'the', 'world', '?']),
#        list(['What', 'is', 'the', 'definition', 'of', 'low', 'island', '?']),
#        list(['What', 'century', 'does', 'Captain', 'Video', 'live', 'in', '?']),
#        list(['What', 'types', 'of', 'water', 'pollution', 'are', 'there', '?']),
#        list(['How', 'many', 'astronauts', 'manned', 'each', 'Project', 'Mercury', 'flight', '?']),
#        list(['What', 'soft', 'drink', 'would', 'provide', 'me', 'with', 'the', 'biggest', 'intake', 'of', 'caffeine', '?']),
#        list(['What', "'s", 'the', 'name', 'of', 'a', 'golf', 'course', 'in', 'Myrtle', 'Beach', '?']),
#        list(['What', 'are', 'some', 'of', 'the', 'significant', 'historical', 'events', 'of', 'the', '1990s', '?']),
#        list(['Name', 'the', 'only', 'extant', 'trilogy', 'of', 'classical', 'Greek', 'plays', '.']),
#        list(['Where', 'is', 'Logan', 'Airport', '?']),
#        list(['What', 'is', 'the', 'difference', 'between', 'Neoclassical', 'art', 'and', 'Romanticism', 'art', '?']),
#        list(['Who', 'was', 'the', 'first', 'person', 'inducted', 'into', 'the', 'U.S.', 'Swimming', 'Hall', 'of', 'Fame', '?']),
#        list(['What', 'golfer', 'has', 'been', 'called', 'Ohio', 'Fats', 'and', 'Blobbo', '?']),
#        list(['Who', 'murdered', 'Leno', 'and', 'Rosemary', 'LaBianca', 'on', 'August', '1']),
#        list(['What', 'is', 'the', 'average', 'cost', 'for', 'four', 'years', 'of', 'medical', 'school', '?']),
#        list(['What', 'does', 'God', 'create', 'in', 'the', 'first', 'sentence', 'of', 'the', 'Bible', '?']),
#        list(['Which', 'of', 'the', 'following', 'men', 'was', 'not', 'married', 'to', 'Rita', 'Hayworth', '?']),
#        list(['What', 'is', 'the', 'current', 'ticket', 'fare', 'from', 'from', 'Cairo', 'to', 'Barbados', '?']),
#        list(['What', 'does', 'NN', 'O', '``', 'mean', 'when', 'used', 'as', 'a', 'prefix', 'in', 'Irish', 'surnames', '?']),
#        list(['How', 'do', 'you', 'find', 'oxidation', 'numbers', '?']),
#        list(['What', 'is', 'the', 'state', 'nickname', 'of', 'Mississippi', '?']),
#        list(['What', 'is', 'Black', 'Hills', ',', 'South', 'Dakota', 'most', 'famous', 'for', '?']),
#        list(['What', '1966', 'boob', 'tube', 'bomb', 'took', 'astronauts', 'back', 'to', 'prehistoric', 'times', '?']),
#        list(['How', 'many', 'students', 'attend', 'the', 'University', 'of', 'Massachusetts', '?']),
#        list(['Who', 'said', ',', '``', 'I', 'shall', 'return', '.', "''", 'during', 'World', 'War', 'Two', '?']),
#        list(['What', 'holidays', 'are', 'celebrated', 'in', 'Ireland', '?']),
#        list(['Who', 'portrayed', 'Etta', 'Place', ',', 'companion', 'to', 'Butch', 'Cassidey', 'and', 'the', 'Sundance', 'Kid', '?']),
#        list(['What', 'are', 'the', 'Greek', 'numerals', '?']),
#        list(['What', "'s", 'the', 'name', 'of', 'the', 'temple', 'that', 'is', 'located', 'near', 'the', 'capital', 'city', 'of', 'Laos', '?']),
#        list(['What', 'is', 'a', 'fear', 'of', 'sleep', '?']),
#        list(['What', 'auto', 'race', 'was', 'Wilbur', 'Reed', 'the', 'first', 'to', 'win', 'three', 'times', '?']),
#        list(['What', 'are', 'the', 'most', 'common', 'breeding', 'birds', 'in', 'the', 'U.S.', '?']),
#        list(['What', 'was', 'organized', 'as', 'a', 'Confederate', 'veterans', "'", 'social', 'club', 'in', 'Pulaski', ',', 'in', 'Tennessee', ',', 'in', '1866', '?']),
#        list(['How', 'do', 'you', 'look', 'up', 'criminal', 'records', 'on', 'the', 'Internet', '?']),
#        list(['Where', 'is', 'the', 'actress', ',', 'Marion', 'Davies', ',', 'buried', '?']),
#        list(['What', 'is', 'an', 'example', 'of', 'an', 'actual', 'case', 'of', 'using', 'the', 'Fourteenth', 'Amendment', '?']),
#        list(['Who', 'was', 'the', 'Charlie', 'perfume', 'woman', '?']),
#        list(['Who', 'portrayed', '``', 'Rosanne', 'Rosanna-Dana', "''", 'on', 'the', 'television', 'show', '``', 'Saturday', 'Night', 'Live', "''", '?'])],
#       dtype=object)

# %%
text = "Who was Galileo?"
tok_text = word_tokenize(text)
print(f"Tokens: {tok_text}")
bigrm_text = bigrams(tok_text)
print(f"Bigrams: {list(bigrm_text)}")
postag_text = pos_tag(tok_text)
print(f"Pos Tags: {list(postag_text)}")
# Out:
# Tokens: ['Who', 'was', 'Galileo', '?']
# Bigrams: [('Who', 'was'), ('was', 'Galileo'), ('Galileo', '?')]
# Pos Tags: [('Who', 'WP'), ('was', 'VBD'), ('Galileo', 'NNP'), ('?', '.')]

# %%
np.array(postag_text)
# Out:
# array([['Who', 'WP'],
#        ['was', 'VBD'],
#        ['Galileo', 'NNP'],
#        ['?', '.']], dtype='<U7')
